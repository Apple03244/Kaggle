# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/stochastic-gradient-descent).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise you'll train a neural network on the *Fuel Economy* dataset and then explore the effect of the learning rate and batch size on SGD.
#
# When you're ready, run this next cell to set everything up!

# %%
# Setup plotting
import matplotlib.pyplot as plt
from learntools.deep_learning_intro.dltools import animate_sgd
#plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex3 import *
# Out:
# 2024-04-23 13:37:43.834431: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-23 13:37:43.834566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-23 13:37:43.962874: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# In the *Fuel Economy* dataset your task is to predict the fuel economy of an automobile given features like its type of engine or the year it was made.
#
# First load the dataset by running the cell below.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

fuel = pd.read_csv('../input/dl-course-data/fuel.csv')

X = fuel.copy()
# Remove target
y = X.pop('FE')

preprocessor = make_column_transformer(
    (StandardScaler(),
     make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse_output=False),
     make_column_selector(dtype_include=object)),
)

X = preprocessor.fit_transform(X)
y = np.log(y) # log transform target instead of standardizing

input_shape = [X.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [50]

# %%
pd.DataFrame(X,columns=preprocessor.get_feature_names_out()).head(3)
# Out:
#    standardscaler__EngDispl  standardscaler__NumCyl  standardscaler__NumGears  \
# 0                  0.913643                1.068005                  0.524148
# 1                  0.913643                1.068005                  0.524148
# 2                  0.530594                1.068005                  0.524148
#
#    standardscaler__TransLockup  standardscaler__TransCreeperGear  \
# 0                     0.685653                         -0.226455
# 1                     0.685653                         -0.226455
# 2                     0.685653                         -0.226455
#
#    standardscaler__IntakeValvePerCyl  standardscaler__ExhaustValvesPerCyl  \
# 0                           0.391659                              0.43492
# 1                           0.391659                              0.43492
# 2                           0.391659                              0.43492
#
#    standardscaler__VarValveTiming  standardscaler__VarValveLift  \
# 0                        0.463841                     -0.447941
# 1                        0.463841                     -0.447941
# 2                        0.463841                     -0.447941
#
#    onehotencoder__Transmission_A4  ...  \
# 0                             0.0  ...
# 1                             0.0  ...
# 2                             0.0  ...
#
#    onehotencoder__CarlineClassDesc_SmallPickupTrucks4WD  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_SmallStationWagons  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_SpecialPurposeVehicleSUV2WD  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_SpecialPurposeVehicleSUV4WD  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_SpecialPurposeVehicleminivan2WD  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_StandardPickupTrucks2WD  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_StandardPickupTrucks4WD  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    onehotencoder__CarlineClassDesc_SubcompactCars  \
# 0                                             0.0
# 1                                             0.0
# 2                                             0.0
#
#    onehotencoder__CarlineClassDesc_VansCargoTypes  \
# 0                                             0.0
# 1                                             0.0
# 2                                             0.0
#
#    onehotencoder__CarlineClassDesc_VansPassengerType
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
# [3 rows x 50 columns]

# %% [markdown]
# Take a look at the data if you like. Our target in this case is the `'FE'` column and the remaining columns are the features.

# %%
# Uncomment to see original data
fuel.head()
# Uncomment to see processed features
#pd.DataFrame(X[:10,:]).head()
# Out:
#    EngDispl  NumCyl Transmission       FE AirAspirationMethod  NumGears  \
# 0       4.7       8          AM6  28.0198  NaturallyAspirated         6
# 1       4.7       8           M6  25.6094  NaturallyAspirated         6
# 2       4.2       8           M6  26.8000  NaturallyAspirated         6
# 3       4.2       8          AM6  25.0451  NaturallyAspirated         6
# 4       5.2      10          AM6  24.8000  NaturallyAspirated         6
#
#    TransLockup  TransCreeperGear          DriveDesc  IntakeValvePerCyl  \
# 0            1                 0  TwoWheelDriveRear                  2
# 1            1                 0  TwoWheelDriveRear                  2
# 2            1                 0      AllWheelDrive                  2
# 3            1                 0      AllWheelDrive                  2
# 4            0                 0      AllWheelDrive                  2
#
#    ExhaustValvesPerCyl CarlineClassDesc  VarValveTiming  VarValveLift
# 0                    2         2Seaters               1             0
# 1                    2         2Seaters               1             0
# 2                    2         2Seaters               1             0
# 3                    2         2Seaters               1             0
# 4                    2         2Seaters               1             0

# %% [markdown]
# Run the next cell to define the network we'll use for this task.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(128, activation='relu'),    
    layers.Dense(64, activation='relu'),
    layers.Dense(1),
])

# %% [markdown]
# # 1) Add Loss and Optimizer
#
# Before training the network we need to define the loss and optimizer we'll use. Using the model's `compile` method, add the Adam optimizer and MAE loss.

# %%
# YOUR CODE HERE
#losser=keras.losses.MAE -> 이부분은 좀더 찾아봐야함

optimizer=keras.optimizers.Adam()
model.compile(loss="mae",optimizer=optimizer)

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Train Model
#
# Once you've defined the model and compiled it with a loss and optimizer you're ready for training. Train the network for 200 epochs with a batch size of 128. The input data is `X` with target `y`.

# %%
# YOUR CODE HERE
history = model.fit(X,y,epochs=200,batch_size=128)

# Check your answer
q_2.check()
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713879478.369118      67 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 9/9 [==============================] - 2s 4ms/step - loss: 2.7001
# Epoch 2/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9996
# Epoch 3/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6156
# Epoch 4/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3571
# Epoch 5/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2457
# Epoch 6/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1756
# Epoch 7/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1368
# Epoch 8/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1181
# Epoch 9/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1107
# Epoch 10/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 11/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0823
# Epoch 12/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0706
# Epoch 13/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 14/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0637
# Epoch 15/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0609
# Epoch 16/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0617
# Epoch 17/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0580
# Epoch 18/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0576
# Epoch 19/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0508
# Epoch 20/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0544
# Epoch 21/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0470
# Epoch 22/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0470
# Epoch 23/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0477
# Epoch 24/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0515
# Epoch 25/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0464
# Epoch 26/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0575
# Epoch 27/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0740
# Epoch 28/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0536
# Epoch 29/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0456
# Epoch 30/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0439
# Epoch 31/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0445
# Epoch 32/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0444
# Epoch 33/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0444
# Epoch 34/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0445
# Epoch 35/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0455
# Epoch 36/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0439
# Epoch 37/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0422
# Epoch 38/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0502
# Epoch 39/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0503
# Epoch 40/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0418
# Epoch 41/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0413
# Epoch 42/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0433
# Epoch 43/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0589
# Epoch 44/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0499
# Epoch 45/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0467
# Epoch 46/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0411
# Epoch 47/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0353
# Epoch 48/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 49/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 50/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 51/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0368
# Epoch 52/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0369
# Epoch 53/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0363
# Epoch 54/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 55/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0422
# Epoch 56/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0440
# Epoch 57/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0377
# Epoch 58/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0345
# Epoch 59/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0328
# Epoch 60/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0326
# Epoch 61/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0308
# Epoch 62/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0324
# Epoch 63/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0337
# Epoch 64/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0329
# Epoch 65/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 66/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0345
# Epoch 67/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 68/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 69/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 70/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0360
# Epoch 71/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 72/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0351
# Epoch 73/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0320
# Epoch 74/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0381
# Epoch 75/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0338
# Epoch 76/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 77/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0380
# Epoch 78/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0435
# Epoch 79/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0405
# Epoch 80/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0367
# Epoch 81/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0325
# Epoch 82/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0295
# Epoch 83/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0344
# Epoch 84/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0348
# Epoch 85/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 86/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0353
# Epoch 87/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0365
# Epoch 88/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0312
# Epoch 89/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0329
# Epoch 90/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0398
# Epoch 91/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0345
# Epoch 92/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0328
# Epoch 93/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0296
# Epoch 94/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0331
# Epoch 95/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0360
# Epoch 96/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0315
# Epoch 97/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0317
# Epoch 98/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 99/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0344
# Epoch 100/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 101/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0291
# Epoch 102/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0386
# Epoch 103/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0374
# Epoch 104/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0400
# Epoch 105/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0322
# Epoch 106/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0306
# Epoch 107/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0284
# Epoch 108/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 109/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 110/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0305
# Epoch 111/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0282
# Epoch 112/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0295
# Epoch 113/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0297
# Epoch 114/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0282
# Epoch 115/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0256
# Epoch 116/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0284
# Epoch 117/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0335
# Epoch 118/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0307
# Epoch 119/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0312
# Epoch 120/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 121/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0322
# Epoch 122/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0348
# Epoch 123/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0452
# Epoch 124/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0464
# Epoch 125/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 126/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0331
# Epoch 127/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0297
# Epoch 128/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0322
# Epoch 129/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0300
# Epoch 130/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0365
# Epoch 131/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0415
# Epoch 132/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 133/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0298
# Epoch 134/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 135/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0283
# Epoch 136/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 137/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0320
# Epoch 138/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0328
# Epoch 139/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 140/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0405
# Epoch 141/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 142/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0375
# Epoch 143/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0377
# Epoch 144/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0338
# Epoch 145/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 146/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 147/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 148/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 149/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0317
# Epoch 150/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0306
# Epoch 151/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0295
# Epoch 152/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0351
# Epoch 153/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0354
# Epoch 154/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 155/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0375
# Epoch 156/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0349
# Epoch 157/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0295
# Epoch 158/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0307
# Epoch 159/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0358
# Epoch 160/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0304
# Epoch 161/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 162/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0274
# Epoch 163/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0281
# Epoch 164/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 165/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0299
# Epoch 166/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0289
# Epoch 167/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0278
# Epoch 168/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0307
# Epoch 169/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0389
# Epoch 170/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0386
# Epoch 171/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0453
# Epoch 172/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0512
# Epoch 173/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0493
# Epoch 174/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0422
# Epoch 175/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0403
# Epoch 176/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 177/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0322
# Epoch 178/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0314
# Epoch 179/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0265
# Epoch 180/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0249
# Epoch 181/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0254
# Epoch 182/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0273
# Epoch 183/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 184/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0310
# Epoch 185/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0368
# Epoch 186/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0296
# Epoch 187/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0311
# Epoch 188/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 189/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0281
# Epoch 190/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0274
# Epoch 191/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 192/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0313
# Epoch 193/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0303
# Epoch 194/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 195/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 196/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0275
# Epoch 197/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0282
# Epoch 198/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0276
# Epoch 199/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0310
# Epoch 200/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0365
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# The last step is to look at the loss curves and evaluate the training. Run the cell below to get a plot of the training loss.

# %%
import pandas as pd

history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5. You can change this to get a different view.
history_df.loc[5:, ['loss']].plot();

# %% [markdown]
# # 3) Evaluate Training
#
# If you trained the model longer, would you expect the loss to decrease further?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# This depends on how the loss has evolved during training: if the learning curves have levelled off, there won't usually be any advantage to training for additional epochs.  Conversely, if the loss appears to still be decreasing, then training for longer could be advantageous.

# %% [markdown]
# With the learning rate and the batch size, you have some control over:
# - How long it takes to train a model
# - How noisy the learning curves are
# - How small the loss becomes
#
# To get a better understanding of these two parameters, we'll look at the linear model, our ppsimplest neural network. Having only a single weight and a bias, it's easier to see what effect a change of parameter has.
#
# The next cell will generate an animation like the one in the tutorial. Change the values for `learning_rate`, `batch_size`, and `num_examples` (how many data points) and then run the cell. (It may take a moment or two.) Try the following combinations, or try some of your own:
#
# | `learning_rate` | `batch_size` | `num_examples` |
# |-----------------|--------------|----------------|
# | 0.05            | 32           | 256            |
# | 0.05            | 2            | 256            |
# | 0.05            | 128          | 256            |
# | 0.02            | 32           | 256            |
# | 0.2             | 32           | 256            |
# | 1.0             | 32           | 256            |
# | 0.9             | 4096         | 8192           |
# | 0.99            | 4096         | 8192           |

# %%
# YOUR CODE HERE: Experiment with different values for the learning rate, batch size, and number of examples
learning_rate = 0.05
batch_size = 2
num_examples = 256

animate_sgd(
    learning_rate=learning_rate,
    batch_size=batch_size,
    num_examples=num_examples,
    # You can also change these, if you like
    steps=50, # total training steps (batches seen)
    true_w=3.0, # the slope of the data
    true_b=2.0, # the bias of the data
)
# Out:
# <video width="800" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # 4) Learning Rate and Batch Size
#
# What effect did changing these parameters have? After you've thought about it, run the cell below for some discussion.

# %%
# View the solution (Run this cell to receive credit!)
q_4.check()
# Out:
# Correct:
#
#
# You probably saw that smaller batch sizes gave noisier weight updates and loss curves. This is because each batch is a small *sample* of data and smaller samples tend to give noisier estimates. Smaller batches can have an "averaging" effect though which can be beneficial.
#
# Smaller learning rates make the updates smaller and the training takes longer to converge. Large learning rates can speed up training, but don't "settle in" to a minimum as well. When the learning rate is too large, the training can fail completely. (Try setting the learning rate to a large value like 0.99 to see this.)

# %% [markdown]
# # Keep Going #
#
# Learn how to [**improve your model's performance**](https://www.kaggle.com/ryanholbrook/overfitting-and-underfitting) by tuning capacity or adding an early stopping callback.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
